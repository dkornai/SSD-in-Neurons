710102489, 18272.32796486091, 19150.80527086384, 23718.887262079064, 21317.715959004392, 28696.925329428992, 35373.35285505125, 27467.057101024893, 34904.83162518302, 24245.97364568082, 26647.144948755493, 24011.71303074671, 33440.702781844804, 36134.69985358712, 45212.29868228405, 48140.55636896047, 50658.8579795022, 26471.449487554906, 39297.21815519766, 54875.54904831626, 68989.75109809663, 67877.01317715959, 53704.24597364568, 46207.90629575403, 51185.944363103954, 35431.91800878478, 38653.00146412884, 37657.39385065886, 42576.866764275255, 39238.65300146413, 50483.162518301615, 36954.61200585652, 49780.38067349927, 40000, 46090.77598828697, 45329.4289897511, 43806.73499267936, 68228.40409956076, 53587.11566617863, 25944.36310395315]

# %%
# print('Fig 5B')
# X1 = np.array(x1)
# Y1 = np.array(y1)
# slope1, intercept1 = np.polyfit(X1, Y1, 1)
# regression_line1 = slope1 * np.linspace(0, 100, 100) + intercept1
# Y1 /= intercept1
# regression_line1 /= intercept1
# plt.scatter(X1, Y1)
# #plt.plot(np.linspace(0, 100, 100), regression_line1, label='Regression Line')
# print(len(X1), slope1, intercept1, regression_line1[-1])

print('Fig 3C')
X2 = np.array(x2)
Y2 = np.array(y2)
slope2, intercept2 = np.polyfit(X2, Y2, 1)
regression_line2 = slope2 * np.linspace(0, 100, 100) + intercept2
#Y2 /= intercept2
#regression_line2 /= intercept2
plt.scatter(X2, Y2)
#plt.plot(np.linspace(0, 100, 100), regression_line2, label='Regression Line')
print(len(X2), slope2, intercept2, regression_line2[-1])

print('Fig 3D')
X3 = np.array(x3)
Y3 = np.array(y3)
slope3, intercept3 = np.polyfit(X3, Y3, 1)
regression_line3 = slope3 * np.linspace(0, 100, 100) + intercept3
#Y3 /= intercept3
#regression_line3 /= intercept3
plt.scatter(X3, Y3)
#plt.plot(np.linspace(0, 100, 100), regression_line3, label='Regression Line')
print(len(X3), slope3, intercept3, regression_line3[-1])

print('Combined and normalized')
X = np.concatenate((X2, X3))
Y = np.concatenate((Y2, Y3))
# X = np.concatenate((X1, X2, X3))
# Y = np.concatenate((Y1, Y2, Y3))
slope, intercept = np.polyfit(X, Y, 1)
regression_line = slope * np.linspace(0, 100, 100) + intercept

plt.plot(np.linspace(0, 100, 100), regression_line, color = 'k', label='Regression Line')
print(len(X), slope, intercept, regression_line[-1])
print(regression_line[-1], regression_line[0])
print('estimation of delta is:')
print(regression_line[0]/regression_line[-1])

plt.xlim(0, 100)
plt.show()
# Out:
# Fig 3C
# 67 310.33360631800485 22490.443788588927 53523.80442038941
# Fig 3D
# 84 137.53626482505317 25317.0010891809 39070.627571686215
# Combined and normalized
# 151 193.77222931452937 24462.39620617471 43839.61913762765
# 43839.61913762765 24462.39620617471
# estimation of delta is:
# 0.5579974618250865
